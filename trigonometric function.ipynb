# %%
import numpy as np

# %%
import pandas as pd

# %%
import math

# %%
x=np.arange(0,5*np.pi,0.1)

# %%
y_sinx=np.sin(x)

# %%
y_cosx=np.cos(x)

# %%
plt.plot(x,y_sinx,"g--")
plt.title("sine")
# Out:
# Text(0.5, 1.0, 'sine')

# %%
plt.plot(x,y_cosx,"r--")
plt.title("cos")
# Out:
# Text(0.5, 1.0, 'cos')
